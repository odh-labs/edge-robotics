# %% [markdown]
# # Using the model server to do an inference using GRPC

# %% [markdown]
# ## First, make sure we have the libraries we need
# Have a look at requirements.txt to see which libraries are used.

# %%
# !pip install -qr requirements.txt

# Only if you don't have PyTorch installed
#!pip install -q -r requirements-torch-cpu.txt
# Out:
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Import the libraries and module where we have all helper code for doing the inference

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image

from remote_infer_grpc import ort_v5

# %% [markdown]
# ## Enter the grpc host and port number, the model name and the YAML file containing your classes

# %%
grpc_host = 'modelmesh-serving.project-name.svc.cluster.local'
grpc_port = 8033
model_name = 'yolo'
classes_file = 'coco.yaml'

# %% [markdown]
# ## Now set the parameters for the inference

# %%
# 1. The image you want to analyze
image_path='images/zidane.jpg'
#image_path='images/bus.jpg' # You can replace this with an image you upload

# 2. Confidence threshold, between 0 and 1 (detections with less score won't be retained)
conf = 0.2

# 3. Intersection over Union Threshold, between 0 and 1 (cleanup overlapping boxes)
iou = 0.6

# %% [markdown]
# ## Launch the inference and show the result

# %%
infer=ort_v5(grpc_host, grpc_port, model_name, 640, classes_file)
img, out, result = infer(image_path, conf, iou)
print(f'{result}')
print('Predictions:')
print(out)
print('Format: each detection is a float64 array shaped as [top_left_corner_x, top_left_corner_y, bottom_right_corner_x, bottom_right_corner_y, confidence, class_index]')
print('The coordinates are relative to a letterboxed representation of the image of size 640x640')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.gcf()
fig.set_size_inches(24, 12)
plt.axis('off')
plt.imshow(img);
# Out:
# images/zidane.jpg processed in 0.34 seconds, inference time 0.07 seconds
# Predictions:
# tensor([[3.5752e+02, 1.5877e+02, 5.8449e+02, 4.9518e+02, 3.8260e-01, 0.0000e+00],
#         [7.1869e+01, 2.3494e+02, 3.6900e+02, 5.0246e+02, 2.1574e-01, 0.0000e+00],
#         [2.0118e+02, 3.5403e+02, 2.6172e+02, 4.9749e+02, 2.1179e-01, 2.7000e+01]])
# Format: each detection is a float64 array shaped as [top_left_corner_x, top_left_corner_y, bottom_right_corner_x, bottom_right_corner_y, confidence, class_index]

# %% [markdown]
# ## Time it on multiple images!

# %%
import os
import time

folder_path = 'images'
infer=ort_v5(grpc_host, grpc_port, model_name, 640, classes_file)

start_time = time.time()

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    # Get the full path of the file
    file_path = os.path.join(folder_path, filename)

    # Check if the file path is a file (not a directory)
    if os.path.isfile(file_path):
        # Do the inference on the file
        img, out, result = infer(file_path, conf, iou)
        print(f'{result}')

end_time = time.time()
execution_time = end_time - start_time
print(f"Executed in {execution_time:.2f} seconds")
# Out:
# images/bus.jpg processed in 0.34 seconds, inference time 0.07 seconds
# images/06f729e89c76c004_jpg.rf.4127f90cb5fc0040b545a0cba49c0dd7.jpg processed in 0.29 seconds, inference time 0.07 seconds
# images/0635078ebd98c7aa_jpg.rf.3849f679b8ada9e8a0ed0decb0e6d034.jpg processed in 0.30 seconds, inference time 0.06 seconds
# images/0348459ccf6e2746_jpg.rf.234d5950ca3bd6de421ee6c8c2dbf204.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/01bce5b2dd400f5d_jpg.rf.4a3fbe55914fbb7a8491935e39e63c1b.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/029e44f5c186d518_jpg.rf.761691070193ef08cfa53ab14374d5f8.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/069412369a393aa0_jpg.rf.2e162b8f348d11d8f33adb5ffec51f9e.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/056c3e43bad4d5f9_jpg.rf.9cdabc97d588216c6a0c633089b5e3fc.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/08d644aa5be91b44_jpg.rf.4dcf8c40712878d2794102541696357c.jpg processed in 0.39 seconds, inference time 0.07 seconds
# images/0242e45d53c9eca2_jpg.rf.fd4c226d597b5f7807653709b3cf55e2.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/03b2dbb7dff0e32d_jpg.rf.b9918364825431b58cc2c4031d25c1c1.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/01c7a957c612291f_jpg.rf.a94ab799531f25ea2879f5294942f395.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/075d92e34d41dce7_jpg.rf.1ce3eb6ec15c0c99338af6ac0f19ccc6.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/030f8954c31837ad_jpg.rf.b53aa214cdd2e9c9b59c5ad714260817.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/023a76e1bb30e7c4_jpg.rf.427c32b1c5ce7507641d6eb2de80b13c.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/049001f82d0190aa_jpg.rf.93b692e475d24b6cae6f29b3a641c21a.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/086acfde3c57d0cb_jpg.rf.e9fa23ef039bb225dfae62f66e6e475a.jpg processed in 0.30 seconds, inference time 0.06 seconds
# images/032c163a8716cba5_jpg.rf.4759c9dfc3e45b97e47ed3ec9c10e00a.jpg processed in 0.27 seconds, inference time 0.06 seconds
# images/07753884f0844a71_jpg.rf.c5cace6e53cf1d89121494ebc9bb8640.jpg processed in 0.30 seconds, inference time 0.06 seconds
# images/05dde453cff88787_jpg.rf.76ab6568426ae0f839e7a8f646e68087.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/04b6f006bc0763b0_jpg.rf.c44c133507906981d6e49317cb8a40ca.jpg processed in 0.30 seconds, inference time 0.06 seconds
# images/024ced6a8f19a9e3_jpg.rf.58366f3720cdce3e02b19f6c32010cd0.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/06afaabccd112387_jpg.rf.42b7c67b14b61133d352d0cc8814aafb.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/017b90b578be59d7_jpg.rf.23542ec6438f705c5d6d26fb72fd3e7f.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/02bb5655ce627b56_jpg.rf.fb6901093c815cc5076c2c4d75631b42.jpg processed in 0.27 seconds, inference time 0.07 seconds
# images/0778a5b9a1a96a70_jpg.rf.e9bdcec2779b5ed3883808a647471f1d.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/0536c4c4cb7cfe80_jpg.rf.dc0950f3f4c6eaf1103f82d493fa80df.jpg processed in 0.27 seconds, inference time 0.07 seconds
# images/0329e6958e4f5069_jpg.rf.4c4d818d1dec588ad7badeca6c592b49.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/03ebb26b5b60a57e_jpg.rf.d3e53d1f76242eb86418076925cfb044.jpg processed in 0.27 seconds, inference time 0.07 seconds
# images/044d4e8762f2c8bc_jpg.rf.7371ecaacd72dba5ec1c49d4bd02e5a3.jpg processed in 0.27 seconds, inference time 0.07 seconds
# images/066a5ac19913781e_jpg.rf.1c524c9729e8146ab8d0c1c8228a3bff.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/zidane.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/05899ed20e05495a_jpg.rf.8f7b8c8ac344aa6fe9ed03e95fc32a28.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/05b9101201c720e5_jpg.rf.02638ec0a28d06d3e3ee1825479c799d.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/0250c7b6f4eb9a4d_jpg.rf.7b0ca86f6fe1b6e710f86ce3f1e147f4.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/0310f445037a4786_jpg.rf.dd925f02d126605c3084159b0c44bd2e.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/034851e4ec3464aa_jpg.rf.9e3cad4c6cf6793aa2b09538016d7d30.jpg processed in 0.30 seconds, inference time 0.07 seconds
# images/0352f1d014fac55f_jpg.rf.e6d850b7e327313abd1e9a5cbfb01c7d.jpg processed in 0.28 seconds, inference time 0.07 seconds
# Executed in 11.54 seconds
